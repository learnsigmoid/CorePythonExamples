# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = "Kenny"
age = 30

print(name)
print(age)
# Out:
# Kenny
# 30

# %%
name = "Python"     # String
age = 25            # Integer
price = 99.99       # Float
is_active = True    # Boolean

print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
age = int(input("Enter your age: "))
print(age + 5)
# Out:
# Enter your age:  60
# 65

# %%
a = 10
b = 3

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)

print(a > b)
print(a == b)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# True
# False

# %%
# if else conditional statement
age = 18

if age >= 18:
    print("You can vote")
else:
    print("You cannot vote")
# Out:
# You can vote

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# while loop

count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#Lists multiple values

fruits = ["apple", "banana", "mango"]

print(fruits)
print(fruits[0])
# Out:
# ['apple', 'banana', 'mango']
# apple

# %%
#Lists multiple values

fruits = ["apple", "banana", "mango"]

print(fruits)
print(fruits[0])

for fruit in fruits:
    print(fruit)
# Out:
# ['apple', 'banana', 'mango']
# apple
# apple
# banana
# mango

# %%
# Dictionaries (Key–Value Data)
student = {
    "name": "John",
    "age": 22,
    "course": "Python"
}

print(student["name"])
# Out:
# John

# %%
#Functions (Reusable Code)

def greet(name):
    print("Hello", name)

greet("Kenny")
# Out:
# Hello Kenny

# %%
#Functions (Reusable Code) with a return

def add(a, b):
    return a + b

result = add(5, 3)
print(result)
# Out:
# 8

# %%
#modules

import math

print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793
